# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score
import random
import itertools
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from imblearn.over_sampling import SMOTE
from sklearn.metrics import roc_curve,auc
target_names = [ '0 Attrition','1 Attrition ']
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
def plot_roc_curve(fper, tper,roc_auc):
    plt.plot(fper,tper,lw=2,alpha=0.8,color='b',
         label='ROC Model(area=%0.3f)'% (roc_auc))
    plt.plot([0, 1], [0, 1], color='green', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic Curve')
    plt.legend()
    plt.show()

# %%
df1 = pd.read_csv("training.csv")
df1['label'] = df1.Attrition
df1 = df1.drop(['Attrition'],axis=1)

df2 = pd.read_csv("testing.csv")
df2['label'] = df2.Attrition
df2 = df2.drop(['Attrition'],axis=1)

df_cat = df1.select_dtypes(include = ['O'])
for i in df_cat.columns:
    df1[i] = pd.Categorical(df1[i])
    df1[i] = df1[i].cat.codes
    df2[i] = pd.Categorical(df2[i])
    df2[i] = df2[i].cat.codes
df_cat.columns
# Out:
# Index(['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole',
#        'MaritalStatus', 'label'],
#       dtype='object')

# %%
df1.columns

# %%
dftrain,dftest = df1,df2
y = dftrain['label']
X = dftrain.drop(['label'],axis = 1)

# %%
models = []
K = 6
num_val_samples = int(len(X)/K)
for i in range(K):
    print('Processing fold #', i)
    x_test = X[i*num_val_samples : (i+1)*num_val_samples]
    y_test = y[i*num_val_samples : (i+1)*num_val_samples]
    x_train = np.concatenate( 
                         [X[: i*num_val_samples],
                         X[(i+1)*num_val_samples :]],
                         axis = 0)
    y_train = np.concatenate(
                         [y[: i*num_val_samples],
                         y[(i+1)*num_val_samples :]],
                         axis = 0)

    categorical_features = df_cat.columns[:-1].tolist()
    lgb_train = lgb.Dataset(x_train,label=y_train,
#                             categorical_feature = categorical_features
                           )
    lgb_valid = lgb.Dataset(dftest.drop(['label'],axis = 1),label=dftest['label'],
#                             categorical_feature = categorical_features,
                            reference=lgb_train)
#     print(x_train)
    def lgb_f1_score(y_hat, data):
        y_true = data.get_label()
        y_hat = np.round(y_hat) # scikits f1 doesn't like probabilities
        return 'f1', f1_score(y_true, y_hat), True

    params = {  
        'boosting_type': 'gbdt',  
        'objective': 'binary',  
        'metric': ['f1'],  
        'tree_learner': 'data',
        'num_leaves': 64,  
        'max_depth': -1,  
        'min_data_in_leaf': 64,  
        'learning_rate': 0.09,  
        'feature_fraction': 0.9,  
        'bagging_fraction': 0.9,  
        'bagging_freq': 10,  
        'lambda_l1': 0,    
        'lambda_l2': 0,  # 越小l2正则程度越高  
        'min_gain_to_split': 0.1,  
        'verbose': 1,  
        'max_bin': 64,
#             'scale_pos_weight':5,
        'min_sum_hessian_in_leaf': 1,
        'task': 'train',

    }  
    params['is_unbalance']=True
    #================================================================================

    results = {}
    gbm = lgb.train(params,
                    lgb_train,
                    num_boost_round= boost_round,
                    valid_sets=(lgb_valid, lgb_train),
                    valid_names=('validate','train'),
                    early_stopping_rounds = early_stop_rounds,
                    evals_result= results,feval=lgb_f1_score)

    models.append(gbm)
# Out:
# Processing fold # 0
# /usr/local/lib/python3.8/dist-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.8/dist-packages/lightgbm/engine.py:260: UserWarning: 'evals_result' argument is deprecated and will be removed in a future release of LightGBM. Pass 'record_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'evals_result' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 160, number of negative: 821
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 2.006743 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 405
# [LightGBM] [Info] Number of data points in the train set: 981, number of used features: 26
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.163099 -> initscore=-1.635349
# [LightGBM] [Info] Start training from score -1.635349
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's f1: 0	validate's f1: 0
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's f1: 0.154696	validate's f1: 0.148148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's f1: 0.311321	validate's f1: 0.253968
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's f1: 0.4329	validate's f1: 0.307692
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's f1: 0.511811	validate's f1: 0.382353
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	train's f1: 0.554745	validate's f1: 0.422535
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	train's f1: 0.561644	validate's f1: 0.421053
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	train's f1: 0.593548	validate's f1: 0.404762
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	train's f1: 0.608696	validate's f1: 0.434783
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	train's f1: 0.619048	validate's f1: 0.442105
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	train's f1: 0.624277	validate's f1: 0.43299
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	train's f1: 0.639118	validate's f1: 0.424242
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	train's f1: 0.645161	validate's f1: 0.438095
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	train's f1: 0.643979	validate's f1: 0.40367
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	train's f1: 0.647959	validate's f1: 0.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	train's f1: 0.654822	validate's f1: 0.432432
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	train's f1: 0.66	validate's f1: 0.414414
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	train's f1: 0.656642	validate's f1: 0.428571
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	train's f1: 0.66	validate's f1: 0.428571
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	train's f1: 0.661654	validate's f1: 0.40708
# Early stopping, best iteration is:
# [15]	train's f1: 0.619048	validate's f1: 0.442105
# Processing fold # 1
# /usr/local/lib/python3.8/dist-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.8/dist-packages/lightgbm/engine.py:260: UserWarning: 'evals_result' argument is deprecated and will be removed in a future release of LightGBM. Pass 'record_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'evals_result' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 158, number of negative: 823
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 1.189638 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 406
# [LightGBM] [Info] Number of data points in the train set: 981, number of used features: 26
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.161060 -> initscore=-1.650361
# [LightGBM] [Info] Start training from score -1.650361
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's f1: 0	validate's f1: 0
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's f1: 0.0952381	validate's f1: 0.0816327
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's f1: 0.235897	validate's f1: 0.241379
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's f1: 0.351852	validate's f1: 0.266667
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's f1: 0.460317	validate's f1: 0.361111
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	train's f1: 0.512821	validate's f1: 0.375
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	train's f1: 0.561873	validate's f1: 0.357143
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	train's f1: 0.603774	validate's f1: 0.348837
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	train's f1: 0.60423	validate's f1: 0.32967
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	train's f1: 0.608696	validate's f1: 0.326087
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	train's f1: 0.617978	validate's f1: 0.361702
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	train's f1: 0.633609	validate's f1: 0.346939
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	train's f1: 0.632708	validate's f1: 0.365385
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	train's f1: 0.62141	validate's f1: 0.373832
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	train's f1: 0.610256	validate's f1: 0.366972
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	train's f1: 0.635417	validate's f1: 0.396396
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	train's f1: 0.627551	validate's f1: 0.410714
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	train's f1: 0.629723	validate's f1: 0.396396
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	train's f1: 0.651282	validate's f1: 0.389381
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	train's f1: 0.643038	validate's f1: 0.403509
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	train's f1: 0.646465	validate's f1: 0.403509
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	train's f1: 0.650124	validate's f1: 0.40708
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	train's f1: 0.646617	validate's f1: 0.403509
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	train's f1: 0.648101	validate's f1: 0.396552
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	train's f1: 0.648241	validate's f1: 0.40678
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	train's f1: 0.648515	validate's f1: 0.413793
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	train's f1: 0.675	validate's f1: 0.396552
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	train's f1: 0.686717	validate's f1: 0.396552
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	train's f1: 0.685	validate's f1: 0.389831
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	train's f1: 0.679803	validate's f1: 0.389831
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	train's f1: 0.681373	validate's f1: 0.386555
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	train's f1: 0.679518	validate's f1: 0.386555
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	train's f1: 0.674699	validate's f1: 0.389831
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	train's f1: 0.687651	validate's f1: 0.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	train's f1: 0.684337	validate's f1: 0.389831
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [41]	train's f1: 0.689157	validate's f1: 0.40678
# Early stopping, best iteration is:
# [31]	train's f1: 0.648515	validate's f1: 0.413793
# Processing fold # 2
# /usr/local/lib/python3.8/dist-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.8/dist-packages/lightgbm/engine.py:260: UserWarning: 'evals_result' argument is deprecated and will be removed in a future release of LightGBM. Pass 'record_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'evals_result' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 159, number of negative: 822
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.900455 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 408
# [LightGBM] [Info] Number of data points in the train set: 981, number of used features: 26
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.162080 -> initscore=-1.642836
# [LightGBM] [Info] Start training from score -1.642836
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's f1: 0	validate's f1: 0
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's f1: 0.156425	validate's f1: 0.218182
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's f1: 0.338164	validate's f1: 0.333333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's f1: 0.426087	validate's f1: 0.3125
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's f1: 0.515873	validate's f1: 0.356164
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	train's f1: 0.544776	validate's f1: 0.390244
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	train's f1: 0.591549	validate's f1: 0.436782
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	train's f1: 0.587459	validate's f1: 0.484211
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	train's f1: 0.588235	validate's f1: 0.489796
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	train's f1: 0.610272	validate's f1: 0.48
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	train's f1: 0.634006	validate's f1: 0.49505
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	train's f1: 0.642857	validate's f1: 0.471698
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	train's f1: 0.628726	validate's f1: 0.481481
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	train's f1: 0.645333	validate's f1: 0.471698
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	train's f1: 0.643979	validate's f1: 0.485981
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	train's f1: 0.642487	validate's f1: 0.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	train's f1: 0.653061	validate's f1: 0.504348
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	train's f1: 0.648101	validate's f1: 0.491525
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	train's f1: 0.644501	validate's f1: 0.474576
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	train's f1: 0.641604	validate's f1: 0.491803
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	train's f1: 0.649874	validate's f1: 0.508197
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	train's f1: 0.658291	validate's f1: 0.512397
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	train's f1: 0.663342	validate's f1: 0.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	train's f1: 0.661728	validate's f1: 0.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	train's f1: 0.666667	validate's f1: 0.516129
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	train's f1: 0.681265	validate's f1: 0.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	train's f1: 0.678133	validate's f1: 0.492063
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	train's f1: 0.673123	validate's f1: 0.471545
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	train's f1: 0.681373	validate's f1: 0.470588
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	train's f1: 0.677966	validate's f1: 0.479339
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	train's f1: 0.687651	validate's f1: 0.483333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	train's f1: 0.693976	validate's f1: 0.455285
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	train's f1: 0.699029	validate's f1: 0.435484
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	train's f1: 0.695652	validate's f1: 0.435484
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	train's f1: 0.699029	validate's f1: 0.435484
# Early stopping, best iteration is:
# [30]	train's f1: 0.666667	validate's f1: 0.516129
# Processing fold # 3
# /usr/local/lib/python3.8/dist-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.8/dist-packages/lightgbm/engine.py:260: UserWarning: 'evals_result' argument is deprecated and will be removed in a future release of LightGBM. Pass 'record_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'evals_result' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 151, number of negative: 830
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.906613 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 407
# [LightGBM] [Info] Number of data points in the train set: 981, number of used features: 26
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.153925 -> initscore=-1.704146
# [LightGBM] [Info] Start training from score -1.704146
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's f1: 0	validate's f1: 0
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's f1: 0.0131579	validate's f1: 0.0816327
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's f1: 0.122699	validate's f1: 0.115385
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's f1: 0.27027	validate's f1: 0.237288
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's f1: 0.388626	validate's f1: 0.30303
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's f1: 0.455696	validate's f1: 0.356164
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	train's f1: 0.527473	validate's f1: 0.425
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	train's f1: 0.57931	validate's f1: 0.516854
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	train's f1: 0.593548	validate's f1: 0.479167
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	train's f1: 0.601227	validate's f1: 0.489796
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	train's f1: 0.625369	validate's f1: 0.466019
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	train's f1: 0.62029	validate's f1: 0.485981
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	train's f1: 0.620112	validate's f1: 0.486486
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	train's f1: 0.608696	validate's f1: 0.45614
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	train's f1: 0.619565	validate's f1: 0.461538
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	train's f1: 0.62766	validate's f1: 0.474576
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	train's f1: 0.624339	validate's f1: 0.469565
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	train's f1: 0.626943	validate's f1: 0.483333
# Early stopping, best iteration is:
# [12]	train's f1: 0.57931	validate's f1: 0.516854
# Processing fold # 4
# /usr/local/lib/python3.8/dist-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.8/dist-packages/lightgbm/engine.py:260: UserWarning: 'evals_result' argument is deprecated and will be removed in a future release of LightGBM. Pass 'record_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'evals_result' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 157, number of negative: 824
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.903499 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 408
# [LightGBM] [Info] Number of data points in the train set: 981, number of used features: 26
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.160041 -> initscore=-1.657925
# [LightGBM] [Info] Start training from score -1.657925
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's f1: 0	validate's f1: 0
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's f1: 0.150289	validate's f1: 0.153846
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's f1: 0.29	validate's f1: 0.3125
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's f1: 0.384279	validate's f1: 0.333333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's f1: 0.452381	validate's f1: 0.352941
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	train's f1: 0.505415	validate's f1: 0.37037
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	train's f1: 0.554054	validate's f1: 0.363636
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	train's f1: 0.574194	validate's f1: 0.382979
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	train's f1: 0.582043	validate's f1: 0.38
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	train's f1: 0.60355	validate's f1: 0.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	train's f1: 0.622857	validate's f1: 0.39604
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	train's f1: 0.621469	validate's f1: 0.392157
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	train's f1: 0.627027	validate's f1: 0.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	train's f1: 0.640212	validate's f1: 0.422018
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	train's f1: 0.645669	validate's f1: 0.418182
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	train's f1: 0.671875	validate's f1: 0.424779
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	train's f1: 0.664948	validate's f1: 0.434783
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	train's f1: 0.658163	validate's f1: 0.420168
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	train's f1: 0.651515	validate's f1: 0.423729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	train's f1: 0.665	validate's f1: 0.429752
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	train's f1: 0.663317	validate's f1: 0.440678
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	train's f1: 0.675	validate's f1: 0.453782
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	train's f1: 0.674938	validate's f1: 0.453782
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	train's f1: 0.668305	validate's f1: 0.470588
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	train's f1: 0.669951	validate's f1: 0.46281
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	train's f1: 0.678133	validate's f1: 0.453782
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	train's f1: 0.689487	validate's f1: 0.45
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	train's f1: 0.694377	validate's f1: 0.453782
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	train's f1: 0.699267	validate's f1: 0.466667
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	train's f1: 0.700483	validate's f1: 0.466667
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	train's f1: 0.698795	validate's f1: 0.448
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	train's f1: 0.70024	validate's f1: 0.439024
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	train's f1: 0.698565	validate's f1: 0.439024
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	train's f1: 0.698337	validate's f1: 0.428571
# Early stopping, best iteration is:
# [29]	train's f1: 0.668305	validate's f1: 0.470588
# Processing fold # 5
# /usr/local/lib/python3.8/dist-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.8/dist-packages/lightgbm/engine.py:260: UserWarning: 'evals_result' argument is deprecated and will be removed in a future release of LightGBM. Pass 'record_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'evals_result' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 165, number of negative: 816
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.899533 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 408
# [LightGBM] [Info] Number of data points in the train set: 981, number of used features: 26
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.168196 -> initscore=-1.598469
# [LightGBM] [Info] Start training from score -1.598469
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	train's f1: 0	validate's f1: 0
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	train's f1: 0	validate's f1: 0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	train's f1: 0.0804598	validate's f1: 0.156863
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	train's f1: 0.243655	validate's f1: 0.245614
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	train's f1: 0.383929	validate's f1: 0.307692
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	train's f1: 0.466926	validate's f1: 0.352941
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	train's f1: 0.52669	validate's f1: 0.473684
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	train's f1: 0.565657	validate's f1: 0.45
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	train's f1: 0.592593	validate's f1: 0.477273
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	train's f1: 0.615385	validate's f1: 0.456522
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	train's f1: 0.630682	validate's f1: 0.428571
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	train's f1: 0.644444	validate's f1: 0.446602
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	train's f1: 0.662983	validate's f1: 0.45283
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	train's f1: 0.654054	validate's f1: 0.46729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	train's f1: 0.65625	validate's f1: 0.473684
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	train's f1: 0.666667	validate's f1: 0.457627
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	train's f1: 0.651515	validate's f1: 0.479339
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	train's f1: 0.65	validate's f1: 0.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	train's f1: 0.653367	validate's f1: 0.470588
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	train's f1: 0.661654	validate's f1: 0.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	train's f1: 0.646914	validate's f1: 0.504202
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	train's f1: 0.653563	validate's f1: 0.491803
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	train's f1: 0.657005	validate's f1: 0.487395
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	train's f1: 0.661836	validate's f1: 0.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	train's f1: 0.665049	validate's f1: 0.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	train's f1: 0.674817	validate's f1: 0.487805
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	train's f1: 0.673123	validate's f1: 0.479339
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	train's f1: 0.679426	validate's f1: 0.459016
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	train's f1: 0.669811	validate's f1: 0.451613
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	train's f1: 0.668235	validate's f1: 0.456693
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	train's f1: 0.668224	validate's f1: 0.476923
# Early stopping, best iteration is:
# [25]	train's f1: 0.646914	validate's f1: 0.504202

# %%
w = []
for model in models:
    y_pred_test = model.predict(dftest.drop('label',axis = 1), num_iteration=model.best_iteration)
    w.append(f1_score(dftest['label'],y_pred_test>0.5,average='binary'))
print(w)
y_pred_train = np.array(models[0].predict(dftrain.drop('label',axis = 1), num_iteration=models[0].best_iteration))*w[0]
y_pred_test = np.array(models[0].predict(dftest.drop('label',axis = 1), num_iteration=models[0].best_iteration))*w[0]

for e,model in enumerate(models[1:]):
    y_pred_train+=np.array(model.predict(dftrain.drop('label',axis = 1), num_iteration=model.best_iteration))*w[e]
    y_pred_test+=np.array(model.predict(dftest.drop('label',axis = 1), num_iteration=model.best_iteration))*w[e]
y_pred_train/=sum(w)
y_pred_test/=sum(w)
print('train accuracy: {:.5} '.format(accuracy_score(dftrain['label'],y_pred_train>0.5)))
print('valid accuracy: {:.5} \n'.format(accuracy_score(dftest['label'],y_pred_test>0.5)))

# lgb.plot_metric(best_r)
# lgb.plot_importance(best_model,importance_type = "gain")
# Out:
# [0.4421052631578947, 0.41379310344827586, 0.5161290322580645, 0.5168539325842697, 0.4705882352941177, 0.504201680672269]
# train accuracy: 0.87086
# valid accuracy: 0.81911

# %%
confusion_matrix(dftest['label'],y_pred_test>0.5)
# Out:
# array([[216,  30],
#        [ 23,  24]])

# %%
print(classification_report(dftest['label'],y_pred_test>0.5))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89       246
#            1       0.44      0.51      0.48        47
#
#     accuracy                           0.82       293
#    macro avg       0.67      0.69      0.68       293
# weighted avg       0.83      0.82      0.82       293

# %%
f1_score(dftest['label'],y_pred_test>0.5,average='binary')
# Out:
# 0.4752475247524752
